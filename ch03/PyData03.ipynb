# %%
# %time print('Hello World!')
# Out:
# Hello World!
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 275 µs

# %%
# %timeit print('Hello World!')
# Out:
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# ...

# %%
test = "AAAAAAAAAAA"
# %whos str
# Out:
# Variable   Type    Data/Info
# ----------------------------
# test       str     AAAAAAAAAAA

# %%
# %who_ls str
# Out:
# ['test']

# %%
ip = !ifconfig eth0| grep "inet"
ip
# Out:
# ['          inetアドレス:169.254.97.83  マスク:255.255.0.0',
#  '          inet6アドレス: fe80::cda5:5adf:6b9e:6153/64 範囲:グローバル']

# %%
# %cd ../ch03/
# %pwd
# Out:
# /home/kimoton/project/private/datascience/pydata-book/ch03
# '/home/kimoton/project/private/datascience/pydata-book/ch03'

# %%
# %run ipython_bug.py
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/project/private/datascience/pydata-book/ch03/ipython_bug.py in <module>()
#      13     throws_an_exception()
#      14
# ---> 15 calling_things()
#
# ~/project/private/datascience/pydata-book/ch03/ipython_bug.py in calling_things()
#      11 def calling_things():
#      12     works_fine()
# ---> 13     throws_an_exception()
#      14
#      15 calling_things()
#
# ~/project/private/datascience/pydata-book/ch03/ipython_bug.py in throws_an_exception()
#       7     a = 5
#       8     b = 6
# ----> 9     assert(a + b == 10)
#      10
#      11 def calling_things():
#
# AssertionError:

# %%
# %debug
# Out:
# > /home/kimoton/project/private/datascience/pydata-book/ch03/ipython_bug.py(9)throws_an_exception()
#       7     a = 5
#       8     b = 6
# ----> 9     assert(a + b == 10)
#      10
#      11 def calling_things():
#
# ipdb> n
